# %%
import pickle as pkl
from PIL import Image
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open("../outputs/JAAD_outputs/goal_cvae_outputs/gaussian_JAAD.pkl", "rb") as f:
    test = pkl.load(f)
test.keys()
# Out:
# dict_keys(['img_path', 'X_global', 'timestep', 'pred_trajs', 'gt_trajs', 'distributions'])

# %% [markdown]
# ## gt_trajs is Ground Truth Trajectories
# ## pred_trajs is Predicted Trajectories
# ## X_global

# %%
test['pred_trajs'][0]
# Out:
# array([[[1115.00415802,  741.854918  ,   48.59925628,  113.66905153],
#         [1113.97006989,  741.61062241,   49.7646153 ,  113.6458692 ],
#         [1113.71109009,  741.6547823 ,   48.88659954,  114.08696115],
#         ...,
#         [1113.54320526,  741.83998346,   47.98236251,  113.05232584],
#         [1113.75297546,  741.35982513,   49.31852818,  114.16678369],
#         [1115.25203705,  741.26120567,   50.20742655,  113.90275776]],
#
#        [[1115.65372467,  741.87345743,   48.52508783,  113.95102948],
#         [1112.77519226,  741.83502674,   49.86247301,  113.90019089],
#         [1113.63716125,  741.75906658,   48.86768103,  114.40861702],
#         ...,
#         [1113.65890503,  741.82794571,   47.86023617,  113.12836647],
#         [1113.22528839,  741.51200294,   49.35468435,  114.51062411],
#         [1114.08840179,  741.57186985,   50.3695035 ,  114.29616541]],
#
#        [[1116.36096954,  741.94729328,   48.66318226,  114.18087333],
# ...

# %%
# image = Image.open(f"../{test['img_path'][0]}")
# image

# %%
cv_image = cv2.imread(f"../{test['img_path'][0]}")

RGB_img = cv2.cvtColor(cv_image, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.show()

# %%
print(f"../{test['img_path'][5]}")
image_number = 5
cv_image = cv2.imread(f"../{test['img_path'][image_number]}")
for testArray in test['pred_trajs'][image_number]:
    for anotherTest in testArray: 
        # rect = cv2.boundingRect(testArray)
        x, y, w, h = int(anotherTest[0]), int(anotherTest[1]), int(anotherTest[2]/8), int(anotherTest[3]/8)
        cv2.rectangle(cv_image, (x, y), (x+w, y+h), (0, 255, 0), 2)


for anotherTest in test['gt_trajs'][image_number]:
    # rect = cv2.boundingRect(testArray)
    x, y, w, h = int(anotherTest[0]), int(anotherTest[1]), int(anotherTest[2]/8), int(anotherTest[3]/8)
    cv2.rectangle(cv_image, (x, y), (x+w, y+h), (0, 0, 255), 2)

RGB_img = cv2.cvtColor(cv_image, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.show()
# Out:
# ../data/JAAD/images/video_0005/00061.png

# %%
print()
cv_image = cv2.imread(f"../{test['img_path'][200]}")
for testArray in test['pred_trajs'][200]:
    for anotherTest in testArray:
        # rect = cv2.boundingRect(testArray)
        x, y, w, h = int(anotherTest[0]), int(anotherTest[1]), int(anotherTest[2]/8), int(anotherTest[3]/8)
        cv2.rectangle(cv_image, (x, y), (x+w, y+h), (0, 255, 0), 2)

RGB_img = cv2.cvtColor(cv_image, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.show()
